# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
import matplotlib.image as mpimage
from sklearn import metrics

# %%
dataset_1=pd.read_csv('train.csv')

# %%
dataset_1.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   60    Male              6.3               3.2                   314
# 1   31  Female              0.8               0.2                   158
# 2   60    Male             19.6               9.5                   466
# 3   34    Male              8.7               4.0                   298
# 4   26  Female              0.9               0.2                   154
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                       118                         114             6.6
# 1                        21                          16             6.0
# 2                        46                          52             6.1
# 3                        58                         138             5.8
# 4                        16                          12             7.0
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.7                        1.27        1
# 1      3.0                        1.00        1
# 2      2.0                        0.40        1
# 3      2.4                        0.70        1
# 4      3.5                        1.00        1

# %%
dataset_1.shape
# Out:
# (466, 11)

# %%
# Checking missing values using heatmap

# %%
sns.heatmap(dataset_1.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
dataset_1.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    3
# Dataset                       0
# dtype: int64

# %%
# filling data with mean values

# %%
dataset_1['Albumin_and_Globulin_Ratio']=dataset_1.fillna(dataset_1['Albumin_and_Globulin_Ratio'].mean)

# %%
dataset_1.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
dataset_1.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  466.000000       466.000000        466.000000            466.000000
# mean    45.321888         3.406438          1.503004            294.877682
# std     15.697936         6.510448          2.823700            252.718859
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            176.000000
# 50%     46.000000         1.000000          0.300000            210.000000
# 75%     58.000000         2.575000          1.300000            298.000000
# max     85.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                466.000000                  466.000000      466.000000
# mean                  82.633047                  114.982833        6.491845
# std                  192.801900                  312.869109        1.096455
# min                   10.000000                   10.000000        2.700000
# 25%                   23.000000                   25.000000        5.800000
# 50%                   36.000000                   42.000000        6.600000
# 75%                   60.000000                   88.000000        7.200000
# max                 2000.000000                 4929.000000        9.600000
#
#           Albumin     Dataset
# count  466.000000  466.000000
# mean     3.149356    1.285408
# std      0.805285    0.452094
# min      0.900000    1.000000
# 25%      2.600000    1.000000
# 50%      3.100000    1.000000
# 75%      3.800000    2.000000
# max      5.500000    2.000000

# %%
dataset_1.groupby('Gender').describe()
# Out:
#           Age                                                     \
#         count       mean        std  min   25%   50%   75%   max
# Gender
# Female  105.0  44.457143  14.937709  8.0  34.0  45.0  54.0  85.0
# Male    361.0  45.573407  15.923454  4.0  33.0  46.0  60.0  78.0
#
#        Alamine_Aminotransferase            ...  Total_Bilirubin        \
#                           count       mean ...              75%   max
# Gender                                     ...
# Female                    105.0  50.323810 ...              1.0  27.7
# Male                      361.0  92.030471 ...              3.1  75.0
#
#        Total_Protiens
#                 count      mean       std  min  25%  50%  75%  max
# Gender
# Female          105.0  6.776190  1.106234  3.6  6.1  6.9  7.6  8.9
# Male            361.0  6.409141  1.081151  2.7  5.7  6.4  7.1  9.6
#
# [2 rows x 72 columns]

# %%
X=dataset_1.iloc[:,:10]
y=dataset_1.iloc[:,10]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Dataset, dtype: int64

# %%
dataset_1.corr()
#Corr b/w Aspartate_Aminotransferase & Alamine_Aminotransferase = 0.784521
#Corr b/w Albumin & Total_Protiens = 0.773420
# Out:
#                                  Age  Total_Bilirubin  Direct_Bilirubin  \
# Age                         1.000000         0.017007          0.004349
# Total_Bilirubin             0.017007         1.000000          0.866070
# Direct_Bilirubin            0.004349         0.866070          1.000000
# Alkaline_Phosphotase        0.112266         0.153458          0.186806
# Alamine_Aminotransferase   -0.066935         0.202096          0.235821
# Aspartate_Aminotransferase  0.005839         0.227747          0.260630
# Total_Protiens             -0.202705         0.006593          0.023680
# Albumin                    -0.281515        -0.211662         -0.213277
# Dataset                    -0.136606        -0.216970         -0.243594
#
#                             Alkaline_Phosphotase  Alamine_Aminotransferase  \
# Age                                     0.112266                 -0.066935
# Total_Bilirubin                         0.153458                  0.202096
# Direct_Bilirubin                        0.186806                  0.235821
# Alkaline_Phosphotase                    1.000000                  0.100744
# Alamine_Aminotransferase                0.100744                  1.000000
# Aspartate_Aminotransferase              0.151079                  0.784251
# Total_Protiens                         -0.023904                 -0.033468
# Albumin                                -0.165888                 -0.010968
# Dataset                                -0.187186                 -0.156944
#
#                             Aspartate_Aminotransferase  Total_Protiens  \
# Age                                           0.005839       -0.202705
# Total_Bilirubin                               0.227747        0.006593
# Direct_Bilirubin                              0.260630        0.023680
# Alkaline_Phosphotase                          0.151079       -0.023904
# Alamine_Aminotransferase                      0.784251       -0.033468
# Aspartate_Aminotransferase                    1.000000       -0.016300
# Total_Protiens                               -0.016300        1.000000
# Albumin                                      -0.075667        0.773420
# Dataset                                      -0.148021        0.048957
#
#                              Albumin   Dataset
# Age                        -0.281515 -0.136606
# Total_Bilirubin            -0.211662 -0.216970
# Direct_Bilirubin           -0.213277 -0.243594
# Alkaline_Phosphotase       -0.165888 -0.187186
# Alamine_Aminotransferase   -0.010968 -0.156944
# Aspartate_Aminotransferase -0.075667 -0.148021
# Total_Protiens              0.773420  0.048957
# Albumin                     1.000000  0.182147
# Dataset                     0.182147  1.000000

# %%
# Encoding Categorical data

# %%
Gender = pd.get_dummies(X['Gender'], prefix = 'Gender', drop_first=True)

# %%
X.drop('Gender',axis=1,inplace=True)

# %%
X=pd.concat([X,Gender],axis=1)

# %%
X.head()
# Out:
#    Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   60              6.3               3.2                   314
# 1   31              0.8               0.2                   158
# 2   60             19.6               9.5                   466
# 3   34              8.7               4.0                   298
# 4   26              0.9               0.2                   154
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                       118                         114             6.6
# 1                        21                          16             6.0
# 2                        46                          52             6.1
# 3                        58                         138             5.8
# 4                        16                          12             7.0
#
#    Albumin Albumin_and_Globulin_Ratio  Gender_Male
# 0      3.7                         60            1
# 1      3.0                         31            0
# 2      2.0                         60            1
# 3      2.4                         34            1
# 4      3.5                         26            0

# %%
#x=X.copy()
#x.drop('Aspartate_Aminotransferase',axis=1,inplace=True)
#ACC=74.35

# %%
#Splitting into train and test sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y,random_state=1)

# %%
#sns.boxplot(data= X).set_title("Outlier Box Plot")

# %%
from sklearn.feature_selection import RFE
# classifier is an object of logistic regression
rfe = RFE(classifier, 3, step=1) #Backward elimination
#ISmei ek ek karke (step=1) features ko remove karte jaate hai and 3 most relevant features select kar rahe hai
rfe = rfe.fit(X, y.values.ravel())
print(rfe.support_)
print(rfe.ranking_)



from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

# The "accuracy" scoring is proportional to the number of correct
# classifications
'''RECURSIVE FEATURE ELIMINATION WITH CROSS VALIDATION

CROSS VALIDATION = K-FOLD, LOOCV, STRATIFIED- K - FOLD'''

rfecv = RFECV(estimator=classifier, step=1, cv=StratifiedKFold(2),scoring='accuracy')
 #2 KA MATLAB K CROSS VALIDATION MEI K=2
              
rfecv.fit(X, y)

print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
''' IT WILL PLOT ALL RELEVANT FEATURES, ABB AGAR HUME ISMEI SE LIMITED FEATURES SELECT KARNE HAI, TOH
HIGHIER VALUE WALE LE LENGE '''

plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
#TO PRINT THE GRID SCORES OF ALL RELEVANT FEATURES
print(rfecv.grid_scores_)
# Out:
# [False False  True False False False  True  True False False]
# [6 2 1 8 5 7 1 1 4 3]
# Optimal number of features : 9
# [0.71459623 0.71459623 0.70814913 0.71242263 0.69744695 0.6931366
#  0.71676982 0.71676982 0.71888815 0.71249632]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred=classifier.predict(X_test)
metrics.accuracy_score(y_pred,y_test)
# Out:
# 0.7435897435897436
